# %%
import os
from datetime import datetime

# %%
Pastas = list(filter((lambda x :not (".") in x),os.listdir()))
Pastas.sort()

# %%
Pastas
# Out:
# ['Crowdrun22',
#  'Crowdrun27',
#  'Crowdrun32',
#  'Crowdrun37',
#  'Duck22',
#  'Duck27',
#  'Duck32',
#  'Duck37',
#  'Oldtown22',
#  'Oldtown27',
#  'Oldtown32',
#  'Oldtown37',
#  'ParkJoy22',
#  'ParkJoy27',
#  'ParkJoy32',
#  'ParkJoy37',
#  'Rushhour22',
#  'Rushhour27',
#  'Rushhour32',
#  'Rushhour37',
#  'Sunflower22',
#  'Sunflower27',
#  'Sunflower32',
#  'Sunflower37']

# %%
for pasta in Pastas:
    os.chdir("./"+pasta)
    entra = datetime.now()
    print("Entering pasta",pasta,"at {}".format(datetime.now().strftime("%H:%M:%S")))
    print("\nExecutanto o TapEncoder nessa pasta")
    os.system("./TAppEncoderStatic -c encoder_randomaccess_main.cfg >Result_random_Bypass.txt")
    sai = datetime.now()
    diferenca = (sai-entra).total_seconds()/60
    print("\n Tempo para executar na pasta = {:.2f} MINUTOS".format(diferenca))
    print("\nTapEncoder Finalizado na pasta {}, saindo da pasta as {}\n".format(pasta,datetime.now().strftime("%H:%M:%S")))
    print(os.getcwd())
    os.chdir("..")
# Out:
# Entering pasta Crowdrun22 at 08:10:44
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 87.40 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun22, saindo da pasta as 09:38:08
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Crowdrun22
# Entering pasta Crowdrun27 at 09:38:08
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 66.71 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun27, saindo da pasta as 10:44:50
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Crowdrun27
# Entering pasta Crowdrun32 at 10:44:50
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 56.50 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun32, saindo da pasta as 11:41:20
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Crowdrun32
# Entering pasta Crowdrun37 at 11:41:20
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 48.72 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun37, saindo da pasta as 12:30:03
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Crowdrun37
# Entering pasta Duck22 at 12:30:03
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 114.71 MINUTOS
#
# TapEncoder Finalizado na pasta Duck22, saindo da pasta as 14:24:46
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Duck22
# Entering pasta Duck27 at 14:24:46
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 79.11 MINUTOS
#
# TapEncoder Finalizado na pasta Duck27, saindo da pasta as 15:43:52
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Duck27
# Entering pasta Duck32 at 15:43:52
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 61.20 MINUTOS
#
# TapEncoder Finalizado na pasta Duck32, saindo da pasta as 16:45:04
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Duck32
# Entering pasta Duck37 at 16:45:04
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 49.91 MINUTOS
#
# TapEncoder Finalizado na pasta Duck37, saindo da pasta as 17:34:59
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Duck37
# Entering pasta Oldtown22 at 17:34:59
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 61.45 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown22, saindo da pasta as 18:36:26
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Oldtown22
# Entering pasta Oldtown27 at 18:36:26
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 36.45 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown27, saindo da pasta as 19:12:53
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Oldtown27
# Entering pasta Oldtown32 at 19:12:53
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 32.25 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown32, saindo da pasta as 19:45:08
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Oldtown32
# Entering pasta Oldtown37 at 19:45:08
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 31.01 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown37, saindo da pasta as 20:16:08
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Oldtown37
# Entering pasta ParkJoy22 at 20:16:08
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 89.94 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy22, saindo da pasta as 21:46:05
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/ParkJoy22
# Entering pasta ParkJoy27 at 21:46:05
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 66.41 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy27, saindo da pasta as 22:52:29
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/ParkJoy27
# Entering pasta ParkJoy32 at 22:52:29
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 52.96 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy32, saindo da pasta as 23:45:27
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/ParkJoy32
# Entering pasta ParkJoy37 at 23:45:27
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 43.93 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy37, saindo da pasta as 00:29:23
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/ParkJoy37
# Entering pasta Rushhour22 at 00:29:23
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 62.09 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour22, saindo da pasta as 01:31:28
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Rushhour22
# Entering pasta Rushhour27 at 01:31:28
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 50.83 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour27, saindo da pasta as 02:22:18
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Rushhour27
# Entering pasta Rushhour32 at 02:22:18
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 44.12 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour32, saindo da pasta as 03:06:25
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Rushhour32
# Entering pasta Rushhour37 at 03:06:25
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 39.37 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour37, saindo da pasta as 03:45:47
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Rushhour37
# Entering pasta Sunflower22 at 03:45:47
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 45.74 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower22, saindo da pasta as 04:31:32
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Sunflower22
# Entering pasta Sunflower27 at 04:31:32
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 40.50 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower27, saindo da pasta as 05:12:02
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Sunflower27
# Entering pasta Sunflower32 at 05:12:02
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 37.98 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower32, saindo da pasta as 05:50:01
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Sunflower32
# Entering pasta Sunflower37 at 05:50:01
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 36.48 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower37, saindo da pasta as 06:26:30
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados bypass aleatorio/Sunflower37
