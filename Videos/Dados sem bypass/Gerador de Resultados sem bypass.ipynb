# %%
import os
from datetime import datetime

# %%
Pastas = list(filter((lambda x :not (".") in x),os.listdir()))
Pastas.sort()

# %%
Pastas
# Out:
# ['Crowdrun22',
#  'Crowdrun27',
#  'Crowdrun32',
#  'Crowdrun37',
#  'Duck22',
#  'Duck27',
#  'Duck32',
#  'Duck37',
#  'Oldtown22',
#  'Oldtown27',
#  'Oldtown32',
#  'Oldtown37',
#  'ParkJoy22',
#  'ParkJoy27',
#  'ParkJoy32',
#  'ParkJoy37',
#  'Rushhour22',
#  'Rushhour27',
#  'Rushhour32',
#  'Rushhour37',
#  'Sunflower22',
#  'Sunflower27',
#  'Sunflower32',
#  'Sunflower37']

# %%
for pasta in Pastas:
    os.chdir("./"+pasta)
    entra = datetime.now()
    print("Entering pasta",pasta,"at {}".format(datetime.now().strftime("%H:%M:%S")))
    print("\nExecutanto o TapEncoder nessa pasta")
    os.system("./TAppEncoderStatic -c encoder_randomaccess_main.cfg >Result_sem_bypass.txt")
    sai = datetime.now()
    diferenca = (sai-entra).total_seconds()/60
    print("\n Tempo para executar na pasta = {:.2f} MINUTOS".format(diferenca))
    print("\nTapEncoder Finalizado na pasta {}, saindo da pasta as {}\n".format(pasta,datetime.now().strftime("%H:%M:%S")))
    print(os.getcwd())
    os.chdir("..")
# Out:
# Entering pasta Crowdrun22 at 01:05:04
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 393.90 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun22, saindo da pasta as 07:38:58
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Crowdrun22
# Entering pasta Crowdrun27 at 07:38:58
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 296.75 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun27, saindo da pasta as 12:35:43
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Crowdrun27
# Entering pasta Crowdrun32 at 12:35:43
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 250.16 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun32, saindo da pasta as 16:45:53
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Crowdrun32
# Entering pasta Crowdrun37 at 16:45:53
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 217.08 MINUTOS
#
# TapEncoder Finalizado na pasta Crowdrun37, saindo da pasta as 20:22:57
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Crowdrun37
# Entering pasta Duck22 at 20:22:57
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 543.05 MINUTOS
#
# TapEncoder Finalizado na pasta Duck22, saindo da pasta as 05:26:00
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Duck22
# Entering pasta Duck27 at 05:26:00
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 372.66 MINUTOS
#
# TapEncoder Finalizado na pasta Duck27, saindo da pasta as 11:38:40
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Duck27
# Entering pasta Duck32 at 11:38:40
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 286.30 MINUTOS
#
# TapEncoder Finalizado na pasta Duck32, saindo da pasta as 16:24:58
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Duck32
# Entering pasta Duck37 at 16:24:58
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 230.42 MINUTOS
#
# TapEncoder Finalizado na pasta Duck37, saindo da pasta as 20:15:23
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Duck37
# Entering pasta Oldtown22 at 20:15:23
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 271.57 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown22, saindo da pasta as 00:46:57
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Oldtown22
# Entering pasta Oldtown27 at 00:46:57
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 159.32 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown27, saindo da pasta as 03:26:16
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Oldtown27
# Entering pasta Oldtown32 at 03:26:16
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 142.49 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown32, saindo da pasta as 05:48:46
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Oldtown32
# Entering pasta Oldtown37 at 05:48:46
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 138.23 MINUTOS
#
# TapEncoder Finalizado na pasta Oldtown37, saindo da pasta as 08:07:00
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Oldtown37
# Entering pasta ParkJoy22 at 08:07:00
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 400.72 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy22, saindo da pasta as 14:47:43
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/ParkJoy22
# Entering pasta ParkJoy27 at 14:47:43
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 296.30 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy27, saindo da pasta as 19:44:01
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/ParkJoy27
# Entering pasta ParkJoy32 at 19:44:01
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 233.29 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy32, saindo da pasta as 23:37:18
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/ParkJoy32
# Entering pasta ParkJoy37 at 23:37:18
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 195.04 MINUTOS
#
# TapEncoder Finalizado na pasta ParkJoy37, saindo da pasta as 02:52:20
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/ParkJoy37
# Entering pasta Rushhour22 at 02:52:20
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 276.59 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour22, saindo da pasta as 07:28:55
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Rushhour22
# Entering pasta Rushhour27 at 07:28:55
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 220.84 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour27, saindo da pasta as 11:09:46
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Rushhour27
# Entering pasta Rushhour32 at 11:09:46
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 191.00 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour32, saindo da pasta as 14:20:45
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Rushhour32
# Entering pasta Rushhour37 at 14:20:45
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 170.53 MINUTOS
#
# TapEncoder Finalizado na pasta Rushhour37, saindo da pasta as 17:11:17
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Rushhour37
# Entering pasta Sunflower22 at 17:11:17
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 204.07 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower22, saindo da pasta as 20:35:21
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Sunflower22
# Entering pasta Sunflower27 at 20:35:21
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 181.79 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower27, saindo da pasta as 23:37:09
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Sunflower27
# Entering pasta Sunflower32 at 23:37:09
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 173.93 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower32, saindo da pasta as 02:31:05
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Sunflower32
# Entering pasta Sunflower37 at 02:31:05
#
# Executanto o TapEncoder nessa pasta
#
#  Tempo para executar na pasta = 168.19 MINUTOS
#
# TapEncoder Finalizado na pasta Sunflower37, saindo da pasta as 05:19:16
#
# /home/tomas/Desktop/TCC/Deeplearning_Video_Compressing/Videos/Dados sem bypass/Sunflower37
