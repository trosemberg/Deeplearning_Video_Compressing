# %%
import numpy as np
import pandas as pd
import os
from Cfg_file import cfg

# %%
config_file = cfg()
#Crowdrun_1920x1080_50_8bit_420.yuv
#DucksTakeOff_1920x1080_50_8bit_420.yuv
#ParkJoy_1920x1080_50_8bit_420.yuv
#OldTownCross_1920x1080_50_8bit_420.yuv
#RushHour_1920x1080_25_8bit_420.yuv
#Sunflower_1920x1080_25_8bit_420.yuv
Video="Crowdrun_1920x1080_50_8bit_420.yuv"
writesplit = 0
bypass=1
depth0=1
depth1=1
depth2=1
QP=22
start = 0
frames = 10

# %%
config_file.choose_config()

# %%
print(config_file.config_2)
config_file.writefile()
# Out:
#         #======== File I/O ===============
# InputFile                     : ../Videos/Crowdrun_1920x1080_50_8bit_420.yuv
# InputBitDepth                 : 8           # Input bitdepth
# InputChromaFormat             : 420         # Ratio of luminance to chrominance samples
# FrameRate                     : 50          # Frame Rate per second
# FrameSkip                     : 0           # Number of frames to be skipped in input
# SourceWidth                   : 1920        # Input  frame width
# SourceHeight                  : 1080        # Input  frame height
# FramesToBeEncoded             : 10           # Number of frames to be coded
#
# Level                         : 4.1
#
# #======== File I/O =====================
# BitstreamFile                 : str.bin
# ReconFile                     : rec.yuv
#
# #======== Profile ================
# Profile                       : main
#
# #======== Unit definition ================
# ...
